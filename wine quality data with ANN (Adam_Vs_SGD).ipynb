# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\Users\Admin\Downloads\wine quality data (1).csv")

# %%
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     bad
# 1      9.8     bad
# 2      9.8     bad
# 3      9.8    good
# 4      9.4     bad

# %%
dataset['quality'].value_counts()
# Out:
# good    855
# bad     744
# Name: quality, dtype: int64

# %%
dataset.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
#Examaning a corelation matrix of all the features 
cmap=sns.diverging_palette(275,150,  s=40, l=65, n=9)
corrmat = dataset.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap=cmap,annot=True, square=True);

# %%
cols=["#ffa600","#bc5090"]
sns.countplot(x=dataset["quality"],palette= cols)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
# Boxen and swarm plot of some non binary features.
feature = ["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol"]
for i in feature:
    plt.figure(figsize=(8,8))
    sns.swarmplot(x=dataset["quality"], y=dataset[i], color="#003f5c", alpha=0.5)
    sns.boxenplot(x=dataset["quality"], y=dataset[i], palette=cols)
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 55.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 31.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 22.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.preprocessing import LabelEncoder
L1=LabelEncoder()
dataset["quality"]=L1.fit_transform(dataset["quality"])
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        0
# 1         9.8        0
# 2         9.8        0
# 3         9.8        1
# 4         9.4        0
# ...       ...      ...
# 1594     10.5        0
# 1595     11.2        1
# 1596     11.0        1
# 1597     10.2        0
# 1598     11.0        1
#
# [1599 rows x 12 columns]

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values
y
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.preprocessing import StandardScaler #MinMaxScaler
m1=StandardScaler()
X=m1.fit_transform(x)
print(X.max())
print(X.min())
# Out:
# 11.127034553969864
# -3.700401226239349

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %%
from keras import callbacks
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# %%
#Adam

# %%
ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units=25, activation='LeakyReLU'))
# ann.add(tf.keras.layers.Dense(units=8, activation='relu'))
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
ann.fit(x_train, y_train, batch_size = 32, epochs = 100)
# ANN = ann.fit(x_train, y_train, batch_size = 32, epochs = 100,callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 1s 3ms/step - loss: 1.8685 - accuracy: 0.4386
# Epoch 2/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.7915 - accuracy: 0.4715
# Epoch 3/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.7491 - accuracy: 0.5129
# Epoch 4/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.7357 - accuracy: 0.5395
# Epoch 5/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.7273 - accuracy: 0.5614
# Epoch 6/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.7124 - accuracy: 0.5559
# Epoch 7/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.7093 - accuracy: 0.5723
# Epoch 8/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6954 - accuracy: 0.5739
# Epoch 9/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6915 - accuracy: 0.5887
# Epoch 10/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.6013
# Epoch 11/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6815 - accuracy: 0.5895
# Epoch 12/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6746 - accuracy: 0.6130
# Epoch 13/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6695 - accuracy: 0.6177
# Epoch 14/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6669 - accuracy: 0.5942
# Epoch 15/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6682 - accuracy: 0.6138
# Epoch 16/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6403 - accuracy: 0.6310
# Epoch 17/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6445 - accuracy: 0.6278
# Epoch 18/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6308 - accuracy: 0.6357
# Epoch 19/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6281 - accuracy: 0.6450
# Epoch 20/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6192 - accuracy: 0.6505
# Epoch 21/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6237 - accuracy: 0.6427
# Epoch 22/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6134 - accuracy: 0.6435
# Epoch 23/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6119 - accuracy: 0.6560
# Epoch 24/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6052 - accuracy: 0.6505
# Epoch 25/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6056 - accuracy: 0.6646
# Epoch 26/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5991 - accuracy: 0.6646
# Epoch 27/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6025 - accuracy: 0.6747
# Epoch 28/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5932 - accuracy: 0.6724
# Epoch 29/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5884 - accuracy: 0.6841
# Epoch 30/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6023 - accuracy: 0.6724
# Epoch 31/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5847 - accuracy: 0.6841
# Epoch 32/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5871 - accuracy: 0.6880
# Epoch 33/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5827 - accuracy: 0.6826
# Epoch 34/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5906 - accuracy: 0.6841
# Epoch 35/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5766 - accuracy: 0.6865
# Epoch 36/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5740 - accuracy: 0.6919
# Epoch 37/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5816 - accuracy: 0.6880
# Epoch 38/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5790 - accuracy: 0.6833
# Epoch 39/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5740 - accuracy: 0.6857
# Epoch 40/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5667 - accuracy: 0.7084
# Epoch 41/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5756 - accuracy: 0.7029
# Epoch 42/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5716 - accuracy: 0.6966
# Epoch 43/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5640 - accuracy: 0.7052
# Epoch 44/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5679 - accuracy: 0.7052
# Epoch 45/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5631 - accuracy: 0.7037
# Epoch 46/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5584 - accuracy: 0.7076
# Epoch 47/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5582 - accuracy: 0.7123
# Epoch 48/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5527 - accuracy: 0.7076
# Epoch 49/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5520 - accuracy: 0.7115
# Epoch 50/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5564 - accuracy: 0.7052
# Epoch 51/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5633 - accuracy: 0.7029
# Epoch 52/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5554 - accuracy: 0.7138
# Epoch 53/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5531 - accuracy: 0.7146
# Epoch 54/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5537 - accuracy: 0.7162
# Epoch 55/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5476 - accuracy: 0.7131
# Epoch 56/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5455 - accuracy: 0.7201
# Epoch 57/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5494 - accuracy: 0.7115
# Epoch 58/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5463 - accuracy: 0.7232
# Epoch 59/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5512 - accuracy: 0.7099
# Epoch 60/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5435 - accuracy: 0.7201
# Epoch 61/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5490 - accuracy: 0.7170
# Epoch 62/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5446 - accuracy: 0.7123
# Epoch 63/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5496 - accuracy: 0.7209
# Epoch 64/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5563 - accuracy: 0.7248
# Epoch 65/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5568 - accuracy: 0.7154
# Epoch 66/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5438 - accuracy: 0.7232
# Epoch 67/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5402 - accuracy: 0.7224
# Epoch 68/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5483 - accuracy: 0.7232
# Epoch 69/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5370 - accuracy: 0.7287
# Epoch 70/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5460 - accuracy: 0.7279
# Epoch 71/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5424 - accuracy: 0.7295
# Epoch 72/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5337 - accuracy: 0.7303
# Epoch 73/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5362 - accuracy: 0.7154
# Epoch 74/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5397 - accuracy: 0.7217
# Epoch 75/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.7256
# Epoch 76/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5305 - accuracy: 0.7404
# Epoch 77/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5585 - accuracy: 0.7091
# Epoch 78/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5301 - accuracy: 0.7310
# Epoch 79/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5278 - accuracy: 0.7389
# Epoch 80/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5351 - accuracy: 0.7279
# Epoch 81/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5304 - accuracy: 0.7318
# Epoch 82/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5380 - accuracy: 0.7232
# Epoch 83/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5361 - accuracy: 0.7271
# Epoch 84/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5290 - accuracy: 0.7326
# Epoch 85/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5310 - accuracy: 0.7263
# Epoch 86/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5283 - accuracy: 0.7412
# Epoch 87/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5359 - accuracy: 0.7287
# Epoch 88/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5317 - accuracy: 0.7310
# Epoch 89/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5268 - accuracy: 0.7256
# Epoch 90/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5323 - accuracy: 0.7271
# Epoch 91/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5413 - accuracy: 0.7217
# Epoch 92/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5264 - accuracy: 0.7334
# Epoch 93/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5292 - accuracy: 0.7287
# Epoch 94/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5292 - accuracy: 0.7365
# Epoch 95/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5385 - accuracy: 0.7248
# Epoch 96/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5271 - accuracy: 0.7287
# Epoch 97/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5340 - accuracy: 0.7256
# Epoch 98/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5246 - accuracy: 0.7365
# Epoch 99/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5324 - accuracy: 0.7349
# Epoch 100/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5202 - accuracy: 0.7451

# %%
y_ann=ann.predict(x_test)
A=[]
for y in y_ann:
    if y>0.5:
        A.append(1)
    else:
        A.append(0)
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
# y_ann=ann.predict(x_test)
# y_ann

# %%
from sklearn.metrics import accuracy_score
a=accuracy_score(y_test,A)*100
print("test accuracy",a)
# Out:
# test accuracy 72.8125

# %%
# ANN_df = pd.DataFrame(ANN,ANN)

# plt.plot(ANN_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
# plt.plot(ANN_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

# plt.title('Training and Validation accuracy')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# %%
# history_df = pd.DataFrame(ANN.ANN)

# plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
# plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
# plt.title('Training and Validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend(loc="best")

# plt.show()

# %%
# confusion matrix
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, A)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, A))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.67      0.68       138
#            1       0.76      0.77      0.76       182
#
#     accuracy                           0.73       320
#    macro avg       0.72      0.72      0.72       320
# weighted avg       0.73      0.73      0.73       320

# %%
#

# %%
ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units=25, activation='LeakyReLU'))
# ann.add(tf.keras.layers.Dense(units=8, activation='relu'))
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
ann.compile(optimizer = 'sgd', loss = 'binary_crossentropy', metrics = ['accuracy'])
ann.fit(x_train, y_train, batch_size = 32, epochs = 100)
# ANN = ann.fit(x_train, y_train, batch_size = 32, epochs = 100,callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 1s 3ms/step - loss: 1.5802 - accuracy: 0.5238
# Epoch 2/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.6122
# Epoch 3/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6939 - accuracy: 0.5966
# Epoch 4/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6685 - accuracy: 0.6122
# Epoch 5/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6502 - accuracy: 0.6380
# Epoch 6/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6686 - accuracy: 0.6083
# Epoch 7/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6513 - accuracy: 0.6185
# Epoch 8/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6578 - accuracy: 0.6192
# Epoch 9/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6446 - accuracy: 0.6239
# Epoch 10/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6559 - accuracy: 0.6067
# Epoch 11/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6516 - accuracy: 0.6325
# Epoch 12/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6382 - accuracy: 0.6388
# Epoch 13/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6352 - accuracy: 0.6302
# Epoch 14/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6512 - accuracy: 0.6114
# Epoch 15/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.6200
# Epoch 16/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6453 - accuracy: 0.6231
# Epoch 17/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6477 - accuracy: 0.6138
# Epoch 18/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6381 - accuracy: 0.6224
# Epoch 19/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6535 - accuracy: 0.6130
# Epoch 20/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6427 - accuracy: 0.6224
# Epoch 21/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6337 - accuracy: 0.6317
# Epoch 22/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6420 - accuracy: 0.6231
# Epoch 23/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6337 - accuracy: 0.6427
# Epoch 24/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6555 - accuracy: 0.6177
# Epoch 25/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6391 - accuracy: 0.6185
# Epoch 26/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6397 - accuracy: 0.6388
# Epoch 27/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6334 - accuracy: 0.6341
# Epoch 28/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6310 - accuracy: 0.6294
# Epoch 29/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.6153
# Epoch 30/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6258 - accuracy: 0.6310
# Epoch 31/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6430 - accuracy: 0.6216
# Epoch 32/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6310 - accuracy: 0.6458
# Epoch 33/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6348 - accuracy: 0.6364
# Epoch 34/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6290 - accuracy: 0.6357
# Epoch 35/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6390 - accuracy: 0.6208
# Epoch 36/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6246 - accuracy: 0.6271
# Epoch 37/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6345 - accuracy: 0.6364
# Epoch 38/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.6294
# Epoch 39/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6242 - accuracy: 0.6341
# Epoch 40/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6268 - accuracy: 0.6396
# Epoch 41/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6301 - accuracy: 0.6333
# Epoch 42/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6152 - accuracy: 0.6482
# Epoch 43/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6311 - accuracy: 0.6357
# Epoch 44/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6299 - accuracy: 0.6294
# Epoch 45/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6244 - accuracy: 0.6341
# Epoch 46/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6382 - accuracy: 0.6255
# Epoch 47/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6227 - accuracy: 0.6403
# Epoch 48/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6183 - accuracy: 0.6364
# Epoch 49/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6157 - accuracy: 0.6364
# Epoch 50/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6193 - accuracy: 0.6513
# Epoch 51/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6235 - accuracy: 0.6482
# Epoch 52/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6225 - accuracy: 0.6450
# Epoch 53/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6147 - accuracy: 0.6443
# Epoch 54/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.6513
# Epoch 55/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6222 - accuracy: 0.6364
# Epoch 56/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6126 - accuracy: 0.6513
# Epoch 57/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6172 - accuracy: 0.6450
# Epoch 58/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6138 - accuracy: 0.6458
# Epoch 59/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6162 - accuracy: 0.6536
# Epoch 60/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6135 - accuracy: 0.6552
# Epoch 61/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6191 - accuracy: 0.6575
# Epoch 62/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6258 - accuracy: 0.6450
# Epoch 63/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6189 - accuracy: 0.6489
# Epoch 64/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6035 - accuracy: 0.6575
# Epoch 65/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6144 - accuracy: 0.6544
# Epoch 66/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6312 - accuracy: 0.6216
# Epoch 67/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6176 - accuracy: 0.6474
# Epoch 68/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6116 - accuracy: 0.6529
# Epoch 69/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6080 - accuracy: 0.6466
# Epoch 70/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6328 - accuracy: 0.6364
# Epoch 71/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6120 - accuracy: 0.6575
# Epoch 72/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6132 - accuracy: 0.6427
# Epoch 73/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6065 - accuracy: 0.6622
# Epoch 74/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6076 - accuracy: 0.6544
# Epoch 75/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6189 - accuracy: 0.6396
# Epoch 76/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6131 - accuracy: 0.6568
# Epoch 77/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6036 - accuracy: 0.6536
# Epoch 78/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6214 - accuracy: 0.6341
# Epoch 79/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6095 - accuracy: 0.6544
# Epoch 80/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6129 - accuracy: 0.6575
# Epoch 81/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6001 - accuracy: 0.6826
# Epoch 82/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6144 - accuracy: 0.6615
# Epoch 83/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6113 - accuracy: 0.6622
# Epoch 84/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6154 - accuracy: 0.6521
# Epoch 85/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6102 - accuracy: 0.6513
# Epoch 86/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6088 - accuracy: 0.6685
# Epoch 87/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6083 - accuracy: 0.6560
# Epoch 88/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6080 - accuracy: 0.6497
# Epoch 89/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6056 - accuracy: 0.6615
# Epoch 90/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5910 - accuracy: 0.6787
# Epoch 91/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6015 - accuracy: 0.6607
# Epoch 92/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6092 - accuracy: 0.6630
# Epoch 93/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6023 - accuracy: 0.6779
# Epoch 94/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6016 - accuracy: 0.6583
# Epoch 95/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6063 - accuracy: 0.6607
# Epoch 96/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5988 - accuracy: 0.6685
# Epoch 97/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5957 - accuracy: 0.6607
# Epoch 98/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.6180 - accuracy: 0.6544
# Epoch 99/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.6599
# Epoch 100/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.6693

# %%
y_ann=ann.predict(x_test)
A=[]
for y in y_ann:
    if y>0.5:
        A.append(1)
    else:
        A.append(0)
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import accuracy_score
a=accuracy_score(y_test,A)*100
print("test accuracy",a)
# Out:
# test accuracy 67.1875

# %%
# confusion matrix
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, A)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, A))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.33      0.47       138
#            1       0.65      0.93      0.76       182
#
#     accuracy                           0.67       320
#    macro avg       0.71      0.63      0.61       320
# weighted avg       0.70      0.67      0.64       320

# %% [raw]
# # Adam Gradient Descent Accuracy-72.8125
# #Stochastic Gradient Descent Accuracy-67.1875

# %%
# Adam Gradient Descent Accuracy is high as comapre to Stochastic Gradient Descent
